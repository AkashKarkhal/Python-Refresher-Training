# %%
import pandas as pd

data = {
    "Name": ["Akash", "Harsh", "Navjot"],
    "Age": [23, 21, 22]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name  Age
# 0   Akash   23
# 1   Harsh   21
# 2  Navjot   22

# %%
import pandas as pd

data = {"name":["Tony", "Steve", "Bruce"],
        "age":[23,45,32]}

df = pd.DataFrame(
    data,
    index=[101,102,103],
    columns=["name", "age"]
)

print(df)
# Out:
#       name  age
# 101   Tony   23
# 102  Steve   45
# 103  Bruce   32

# %%
name=["Akash", "Harsh","Navjot"]
age = [23,22,21]
data=zip(name,age)
df=pd.DataFrame(data,columns=["name","age"])
print(df)
# Out:
#      name  age
# 0   Akash   23
# 1   Harsh   22
# 2  Navjot   21

# %%
df=pd.read_csv("hero.csv")
print(df)
# df.info()      # Column names, data types
# df.shape       # Rows and columns
# df.columns     # Column names
# df.dtypes      # Data types
df.describe()
x = df.loc[1]
print(x)
# Out:
#               Hero      Team  Power   Age
# 0         Iron Man  Avengers     95    48
# 1  Captain America  Avengers     90   105
# 2             Thor  Avengers     99  1500
# 3             Hulk  Avengers     98    45
# 4       Spider-Man  Avengers     85    21
# 5   Doctor Strange  Avengers     97    45
# 6    Black Panther  Avengers     92    40
# 7             Loki    Asgard     93  1050
# 8    Scarlet Witch  Avengers    100    32
# 9          Hawkeye  Avengers     75    43
# Hero     Captain America
# Team            Avengers
# Power                 90
# Age                  105
# Name: 1, dtype: object

# %%
import pandas as pd
 
# Sample DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],'Age': [25, 30, 35],'City': ['NYC', 'LA', 'Chicago']}
 
df = pd.DataFrame(data, index=['a', 'b', 'c'])
# Using loc with condition
print(df.loc[df['Age'] > 28])
# Out:
#       Name  Age     City
# b      Bob   30       LA
# c  Charlie   35  Chicago
